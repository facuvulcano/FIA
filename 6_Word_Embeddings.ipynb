# %%
import nltk
nltk.download('gutenberg')
nltk.download('abc')
nltk.download('webtext')
nltk.download('brown')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\Facu\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package abc to
# [nltk_data]     C:\Users\Facu\AppData\Roaming\nltk_data...
# [nltk_data]   Package abc is already up-to-date!
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\Facu\AppData\Roaming\nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\Facu\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %% [markdown]
# This piece of code is used to download several corpora from the Natural Languaje Toolkist (nltk) libraty. The 'nltk' library is a leading platform for builidng Python programs to work with human language data. It provides easy-to-use interfaces to over 50 corpora and lexical resources.
#
# - nltk.download('gutenberg'): This command downlaods the Gutenberg corpus, a collection of texts from project Gutenberg, which includes classic literature such as works by Shakespeare, Jane Austen, and more.
#
# - nltk.download('abc'): This command downloads the ABC corpus, a collection of Austarlian Broadcasting Corporation content.
#
# - nltk.download('webtext'): This command download the Webtext corpus, a collectio of web content including texts like "Firefox" discussions, movie scripts, and more.
#
# - nltk.download('brown'): This command downloads the Brown corpus, one of the first widely available text corpora, consting of 500 samples of english-language text from a wide range of sources.
#
# By downloading these corpora, we ensure that we have access to a wide variety of text data for my NLP tasks.

# %% [markdown]
# # Descarga de datos

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# These file IDs represent classic literature texts, including works by authors such as Jane Austen, William Shakespeare, and other.

# %%
texts = []
for f in nltk.corpus.gutenberg.fileids():
  texts.append(nltk.corpus.gutenberg.raw(f))

# %% [markdown]
# After executing this code, the texts list will contain the raw text of all the files in the Gutenberg corpus. Each element in the list will be a string representing the content of one of the texts in the corpus. This list can then be used for further text processing or analysis.

# %%
texts[0][:200]
# Out:
# '[Emma by Jane Austen 1816]\n\nVOLUME I\n\nCHAPTER I\n\n\nEmma Woodhouse, handsome, clever, and rich, with a comfortable home\nand happy disposition, seemed to unite some of the best blessings\nof existence; an'

# %%
texts[-1][:200]
# Out:
# '[Leaves of Grass by Walt Whitman 1855]\n\n\nCome, said my soul,\nSuch verses for my Body let us write, (for we are one,)\nThat should I after return,\nOr, long, long hence, in other spheres,\nThere to some g'

# %%
nltk.corpus.abc.fileids()
# Out:
# ['rural.txt', 'science.txt']

# %%
for f in nltk.corpus.abc.fileids():
  texts.append(nltk.corpus.abc.raw(f))

# %%
texts[-1][:200]
# Out:
# 'Cystic fibrosis affects 30,000 children and young adults in the US alone\r\nInhaling the mists of salt water can reduce the pus and infection that fills the airways of cystic fibrosis sufferers, althoug'

# %%
nltk.corpus.webtext.fileids()
# Out:
# ['firefox.txt',
#  'grail.txt',
#  'overheard.txt',
#  'pirates.txt',
#  'singles.txt',
#  'wine.txt']

# %%
for f in nltk.corpus.webtext.fileids():
  texts.append(nltk.corpus.webtext.raw(f))

# %%
texts[-1][:200]
# Out:
# 'Lovely delicate, fragrant Rhone wine. Polished leather and strawberries. Perhaps a bit dilute, but good for drinking now. ***\nLiquorice, cherry fruit. Simple and coarse at the finish. **\nThin and comp'

# %%
nltk.corpus.brown.fileids()[:10]
# Out:
# ['ca01',
#  'ca02',
#  'ca03',
#  'ca04',
#  'ca05',
#  'ca06',
#  'ca07',
#  'ca08',
#  'ca09',
#  'ca10']

# %%
for f in nltk.corpus.brown.fileids():
  texts.append(nltk.corpus.brown.raw(f))

# %%
len(texts)
# Out:
# 526

# %% [markdown]
# # Tokenizado

# %%
import re
from tqdm import tqdm

# %%
TOKENIZER_REGEX = r"\w+(?:'\w+)?|[^\w\s]"
s = "I don't like to eat Cici's food (it is true)"
print(re.findall(TOKENIZER_REGEX, s))
# Out:
# ['I', "don't", 'like', 'to', 'eat', "Cici's", 'food', '(', 'it', 'is', 'true', ')']

# %% [markdown]
# This piece of code defines a regular expression pattern for tokenizing text and then uses it to tokenize a given sentence.

# %%
tokenized_texts = []
for t in tqdm(texts):
  tokenized_texts.append(re.findall(TOKENIZER_REGEX, t.lower()))
# Out:
# 100%|██████████| 526/526 [00:03<00:00, 147.98it/s]

# %% [markdown]
# After executing this code, the tokenized_tests list will contain the tokenized version of each text in the texts list. Each element in tokenized_texts will be a list of tokens (words and punctuation) derived from the corresponding text in texts.

# %%
texts[0][:1000]
# Out:
# "[Emma by Jane Austen 1816]\n\nVOLUME I\n\nCHAPTER I\n\n\nEmma Woodhouse, handsome, clever, and rich, with a comfortable home\nand happy disposition, seemed to unite some of the best blessings\nof existence; and had lived nearly twenty-one years in the world\nwith very little to distress or vex her.\n\nShe was the youngest of the two daughters of a most affectionate,\nindulgent father; and had, in consequence of her sister's marriage,\nbeen mistress of his house from a very early period.  Her mother\nhad died too long ago for her to have more than an indistinct\nremembrance of her caresses; and her place had been supplied\nby an excellent woman as governess, who had fallen little short\nof a mother in affection.\n\nSixteen years had Miss Taylor been in Mr. Woodhouse's family,\nless as a governess than a friend, very fond of both daughters,\nbut particularly of Emma.  Between _them_ it was more the intimacy\nof sisters.  Even before Miss Taylor had ceased to hold the nominal\noffice o
# ...

# %%
print(tokenized_texts[0][:100])
# Out:
# ['[', 'emma', 'by', 'jane', 'austen', '1816', ']', 'volume', 'i', 'chapter', 'i', 'emma', 'woodhouse', ',', 'handsome', ',', 'clever', ',', 'and', 'rich', ',', 'with', 'a', 'comfortable', 'home', 'and', 'happy', 'disposition', ',', 'seemed', 'to', 'unite', 'some', 'of', 'the', 'best', 'blessings', 'of', 'existence', ';', 'and', 'had', 'lived', 'nearly', 'twenty', '-', 'one', 'years', 'in', 'the', 'world', 'with', 'very', 'little', 'to', 'distress', 'or', 'vex', 'her', '.', 'she', 'was', 'the', 'youngest', 'of', 'the', 'two', 'daughters', 'of', 'a', 'most', 'affectionate', ',', 'indulgent', 'father', ';', 'and', 'had', ',', 'in', 'consequence', 'of', 'her', "sister's", 'marriage', ',', 'been', 'mistress', 'of', 'his', 'house', 'from', 'a', 'very', 'early', 'period', '.', 'her', 'mother', 'had']

# %%
import scipy
from scipy.linalg import triu

# %% [markdown]
# # Entrenamiento de word embeddings

# %%
from gensim.models import Word2Vec

# %%
model = Word2Vec(sentences=tokenized_texts,
                 vector_size=150, window=5,
                 min_count=10, workers=1, epochs=10)

# %% [markdown]
# This piece of code trains a Word2Vec model on the tokenized texts. Word2Vec is a popular algorithm for learning vector representations of words, capturing semanting meaning and relationships between words.
#
# The code initializes and trains a Word2Vec model with the following parameters:
#
# - sentences=tokenized_texts: The tokenized_texts list, where each element is a list of tokens (words and punctuation) from the texts. This is the input data for training the model.
#
# - vector_size=150: The size of the word vectors (i.e., the number of dimensions of the word embeddings). In this case, each word will be represented by a 150-dimensional vector.
#
# - window=5: The maximum distance between the current and predicted word within a sentence. A window size of 5 means the model will consider 5 words to the left and 5 words to the right of the target word for context.
#
# - min_count=10: Ignores all words with a total frequency lower than this. Only words that appear at least 10 times in the corpus will be included in the training.
#
# - workers=1: The number of workers threads used for training the model. In this case, only 1 worker thread is used.
#
# - epochs=10: The number of iterations (epochs) over the corpus for training the model. The model will go through the entire corpus 10 times.
#
# After running this code, the model variable will contain the trained Word2Vec model. This model can be used to obtain vector representations of words, find similar words, and perform various other tasks related to word embeddings.
#
# The Word2Vec model captures semantic and syntactic similarities between words, enabling various natural language processing tasks such as text classification, clustering and more.

# %%
len(model.wv)
# Out:
# 19429

# %% [markdown]
# This line of code returns the number of unique words (vocabulary size) in the trained Word2Vec model.
#
# The oput is 19429, this means there are 19429 unique words in the vocabulary of the trained Word2Vec model. These words are those that appeared at least 10 times (as specified by min_count=10) in the training corpus.

# %%
model.wv.most_similar('dog', topn=10)
# Out:
# [('shadow', 0.7472572922706604),
#  ('chair', 0.7168091535568237),
#  ('pencil', 0.7037463188171387),
#  ('drum', 0.7023730278015137),
#  ('carriage', 0.7022029757499695),
#  ('bullet', 0.6939827799797058),
#  ('policeman', 0.6924730539321899),
#  ('rifle', 0.6912440657615662),
#  ('restaurant', 0.6835646033287048),
#  ('envelope', 0.6833434104919434)]

# %% [markdown]
# This line of code retrieves the top 10 words that are most similar to the word dog based on the trained Word2Vec model. The 'most_similar' mehtod finds words in the model's vocabulary that have similar vector representations to the specified word.
#
# - model.vw: This accesses the word vectors in the trained Word2Vec model.
#
# - most_similar('dog', topn=10): This method finds the words that are most similar to 'dog'. The topn=10 argument specifies that the top 10 most similar words should be returned.

# %%
model.wv.most_similar('married', topn=10)
# Out:
# [('named', 0.7798156142234802),
#  ('killed', 0.7493572235107422),
#  ('employed', 0.7437532544136047),
#  ('spoken', 0.7417250275611877),
#  ('hired', 0.7309127449989319),
#  ('created', 0.7285154461860657),
#  ('born', 0.7257478833198547),
#  ('composed', 0.7202786803245544),
#  ('persuaded', 0.7199586033821106),
#  ('mentioned', 0.7173994779586792)]

# %%
model.wv.most_similar('china', topn=10)
# Out:
# [('germany', 0.8442509770393372),
#  ('india', 0.8270453214645386),
#  ('africa', 0.823635995388031),
#  ('berlin', 0.8195011019706726),
#  ('virginia', 0.8162835240364075),
#  ('russia', 0.8057820200920105),
#  ('massachusetts', 0.8036941289901733),
#  ('katanga', 0.7890212535858154),
#  ('maryland', 0.7876358032226562),
#  ('asia', 0.784088134765625)]

# %%
model.wv.most_similar('argentina', topn=10)
# Out:
# [('daly', 0.8120667934417725),
#  ('eleazar', 0.8069273233413696),
#  ('trinity', 0.787875771522522),
#  ('fletcher', 0.7834154963493347),
#  ("fishermen's", 0.7798908948898315),
#  ('canterbury', 0.7777469754219055),
#  ('gresham', 0.7739821672439575),
#  ('cairns', 0.7732320427894592),
#  ('pilate', 0.7708531618118286),
#  ('clifford', 0.7699301838874817)]

# %%
model.wv.most_similar(input("Ingrese palabra: "), topn=10)
# Out:
# [('gresham', 0.9140377640724182),
#  ('hino', 0.8981378078460693),
#  ('yin', 0.8964382410049438),
#  ('weaver', 0.8958525061607361),
#  ('chapman', 0.8949963450431824),
#  ('littlepage', 0.894830584526062),
#  ('oscar', 0.894778311252594),
#  ('switzerland', 0.8902273178100586),
#  ('forbes', 0.8901425004005432),
#  ('schwartz', 0.8899844288825989)]

# %% [markdown]
# # t-SNE

# %%
top_500_palabaras = []
embs = []

for i in range(1000):
  top_500_palabaras.append(model.wv.index_to_key[i])
  embs.append(model.wv[model.wv.index_to_key[i]])

print(top_500_palabaras)
# Out:
# ['/', ',', 'the', '.', 'in', 'nn', 'and', 'of', 'at', 'to', '-', 'a', 'jj', ':', 'nns', 'that', '"', "'", 'np', 'i', 'he', 'cc', 'it', 'is', 'for', 'rb', '`', 'be', ';', 'vb', 'was', 'with', 'tl', 'vbn', 'his', 'not', 'vbd', 'as', 'you', '$', 'on', 'but', 'cs', 'they', '?', 'have', 'pps', 'all', 'from', 'this', 'vbg', 'are', 'by', 'pp', 'had', 'him', 'her', 'ppss', 'cd', '!', 'which', 'md', 'said', 'my', 'she', 'or', 'them', 'will', 'their', 'so', 'me', 'shall', 'one', 'were', 'when', 'an', '*', 'ppo', 'bez', 'there', 'we', 'no', 'bedz', 'out', 'what', 'if', 'ap', 'do', 'up', 'dt', 'unto', 'more', 'ql', 'lord', '(', ')', 'would', 'been', 'has', 'says', 'who', 'man', 'like', 'vbz', 'then', 'into', 'your', 'now', 'could', 'hl', 'thou', 'about', 'than', '1', 'some', 'very', 'rp', 'can', 'god', 'time', 'wdt', 'thy', '2', 'other', 'any', 'new', 'only', 'these', 'people', 'after', 'over', 'hvd', 'upon', 'before', 'know', 'two', 'may', 'come', 'thee', 'good', 'our', 'did', 'how', 'us', 'ber
# ...

# %% [markdown]
# This piece of code retrieves the top 500 words from the vocabulary of the trained Word2Vec model and their corresponding vector representations (embeddings). It stores these words in the top_500_palabras list and their embeddings in the 'embs' list.
#
# The index_to_key attribute of the Word2Vec model is indeed ordered by frequency, with the most frequent words first. Therefore, iterating over the first 500 indices of index_to_key will give you the top 500 most frequent words.

# %%
import numpy as np
embs = np.asarray(embs)
embs.shape
# Out:
# (1000, 150)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, metric='cosine')
X_tsne = tsne.fit_transform(embs)

# %% [markdown]
# Here the code converts the list of embeddings to a NumPy array, computes its shape, and then applies the t-SNE algorithm to reduce the dimensionality of the embeddings for visualization.
#
# t-SNE (t-Distributed Stochastic Neighbor Embedding) is a machine learning algorithm for dimensionality reduction that is particularly well-suited for the visualization of high-dimensional data. It is a non-linear technique that is primarily used for reducing the dimensions of data to two or three dimensions for visulization purposes.

# %%
import matplotlib.pyplot as plt

plt.figure(dpi=150)
for i in range(len(X_tsne)):
    plt.scatter(X_tsne[i, 0], X_tsne[i, 1], s=1, color='grey', alpha=0.5)
    plt.annotate(top_500_palabaras[i],
                 xy=(X_tsne[i, 0], X_tsne[i, 1]),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom', fontsize=6, alpha=0.7)
plt.show()

# %% [markdown]
# The output shows a t-SNE visualization of the top 500 words embeddings from the Word2Vec model. The points represent the words, and they are annotated with the words themselves. This visuzalizations helps to understand the clustering and relationships between different words in a 2D space.
#
# The clusters indicate groups of words that have similar vector representations, which typically means they appear in similar contexts in the training corpus. For example, words related to similar topics or with similar meanings tend to cluster together.

# %% [markdown]
# # Cargamos los embeddings de google
# Del paper original de word2vec, fueron entrenados durante más tiempo

# %%
from gensim.models import KeyedVectors
from gensim import downloader

downloader.load('word2vec-google-news-300')
model = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       2 from gensim import downloader
#       4 model_path = downloader.load('word2vec-google-news-300')
# ----> 5 model = KeyedVectors.load_word2vec_format(model_path, binary=True)
#
# File c:\Users\Facu\anaconda3\envs\NLP\lib\site-packages\gensim\models\keyedvectors.py:1719, in KeyedVectors.load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype, no_header)
#    1672 @classmethod
#    1673 def load_word2vec_format(
#    1674         cls, fname, fvocab=None, binary=False, encoding='utf8', unicode_errors='strict',
#    1675         limit=None, datatype=REAL, no_header=False,
#    1676     ):
#    1677     """Load KeyedVectors from a file produced by the original C word2vec-tool format.
#    1678
#    1679     Warnings
#    (...)
#    1717
#    1718     """
# ...

# %%
model.most_similar('dog', topn=10)

# %%
model.most_similar('married', topn=10)

# %%
model.most_similar('china', topn=10)

# %%
model.most_similar('argentina', topn=10)

# %%
model.most_similar(input("Ingrese palabra: "), topn=10)

# %% [markdown]
# # Analogias

# %%
model.most_similar(positive=['woman','king'], negative=['man'], topn=10)

# %%
model.most_similar('king', topn=10)

# %% [markdown]
# King de por sí ya está cerca de queen.

# %% [markdown]
# ## Del paper de microsoft

# %% [markdown]
# [link](https://papers.nips.cc/paper_files/paper/2016/file/a486cd07e4ac3d270571622f4f316ec5-Paper.pdf)

# %%
model.most_similar('computer_programmer', topn=10)

# %%
model.most_similar(positive=['woman', 'medic'], negative=['man'], topn=10)
